# %% [markdown]
# **Vertical Strategy: Use text column to predict tex_paragraph column**
#
# **Outline**
#
# 1. ✅ filter out stopwords in text column
#     - word tokenize text column
# 2. ✅  use token match in big string to define candidate paragraphs
#     - merge overlapping paragraphs
# 3. ✅ Score/rank paragraphs
#     - some terms will be more relevant/weighted than others
#     - also score them by requency
# 4. ✅ Check similarity between predicted paragraphs and actual paragraphs

# %% [markdown]
# # Vertical Pipeline: turn vertical strategy into something easily iterable
# - like a function callable on an html that returns a nominated paragraph

# %%
import os
import glob

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

from collections import Counter

from bs4 import BeautifulSoup
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize

import datetime

# %% [markdown]
# ## Generate parameters from curated training data
#
# ### read in the vertical training subset data frame

# %%
### read in the vertical training subset
vert_training_subset_df = pd.read_csv('data/share_repurchase_paragraphs.csv', index_col=[0])
vert_training_subset_df.head(2)
# Out:
#             accession_number               data_key_friendly_name  \
# ticker
# A       0001090872-17-000018  Share Repurchase Authorization Date
# A       0001090872-17-000018       Share Repurchase Authorization
#
#                                                      text  data_value  \
# ticker
# A                                            May 28, 2015    20150528
# A       The 2015 share repurchase program authorizes t...  1140000000
#
#         reported_data_value reported_units  \
# ticker
# A               20200000.00           ones
# A                      1.14       billions
#
#                                            paragraph_text
# ticker
# A       On May 28, 2015 we  announced that our board  ...
# A       On May 28, 2015 we  announced that our board  ...

# %%
### these are the only dkfns that I'm currently working with
print(set(vert_training_subset_df.data_key_friendly_name))
# Out:
# {'Share Repurchase Authorization', 'Share Repurchase Utilization', 'Unknown Share Repurchase Data', 'Share Repurchase Intention', 'Share Repurchase Authorization Date', 'Amount Spent on Share Repurchases', 'Share Repurchase Count'}

# %% [markdown]
# ### generate key_tokens from text colum

# %%
### compile a string from the text column

text_list = [t.lower() for t in vert_training_subset_df.text]
#print('This is what the text_list looks like: ')
#print("----------------------------")
#print(text_list[0:3])
#print("----------------------------")
text_string = ''
for t in text_list:
    text_string = text_string + t + ' '
#print("")
#print("And now this is what the flattened text_string looks like: ")
#print("----------------------------")
#print(text_string[0:250])
#print("----------------------------")

# %%
### tokenize the text string

text_tokens = [w for w in word_tokenize(text_string) if w.isalpha()]
no_stops = [t for t in text_tokens if t not in stopwords.words('english')]
#print(no_stops[0:10])

### limit ourselves to the 30 most common tokens
    # although this can be modulated if necessary
key_tokens = pd.DataFrame(Counter(no_stops).most_common(30))
key_tokens.columns = ['key_tok', 'kt_count']

# %% [markdown]
# can probably improve the above list of key_tokens by using less than 30 terms.... maybe

# %% [markdown]
# #### 🤔 I could enhance my key_tokens by doing tf-idf
# - between the text column and the the html text - the text column
#     - which terms are prominent in text column that are not prominent in the rest of the html
#     - which terms are prominent in the noisy signal that are not prominent in the noise?
# - I could also enhance it by removing noisy words like 'total'

# %% [markdown]
# ### define paragraph margins
# as the standard deviation of paragraph lengths

# %%
par_lengths = [len(par) for par in vert_training_subset_df.paragraph_text]
margin = int(np.std(par_lengths))

# %% [markdown]
# ## This will be the beginning of the loop
# 1. read in a filing
# 2. call a function that
#     - defines candidate paragraphs
#     - ranks or scores candidate paragraphs to select top nominee(s)
#     - validates if predicted nominee is a good match to actual paragraph in the training csv.

# %% [markdown]
# ### Stage filings to be read in iterably

# %%
# initialize a list of paths
training_filings_list = []

# populate the list
for root, dirs, files in os.walk('data/nc_training_filings/'):
    training_filings_list += glob.glob(os.path.join(root, '*.html'))
#print(training_filings_list[0:3])

# %% [markdown]
# # need to isolate only those filings which are in my vertical training df

# %%
len(set(vert_training_subset_df.accession_number))
# Out:
# 435

# %%
len(set(['data/nc_training_filings/' + an + '.html' for an in vert_training_subset_df.accession_number]))
# Out:
# 435

# %%
vert_training_subset_filings_list = list(set(['data/nc_training_filings/' + an + '.html' for an in vert_training_subset_df.accession_number]))
vert_training_subset_filings_list
assert len(vert_training_subset_filings_list) == len(set(vert_training_subset_df.accession_number))

# %%
len(vert_training_subset_filings_list)
# Out:
# 435

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2018, 6, 3, 11, 29, 45, 421185)

# %% [markdown]
# # for now, lets practice on only filings in vertical_training_subset

# %%
# initialize some score keeping lists
total_inclusion = []
inclusion_rates = []

#for filing in training_filings_list:
#for filing in vert_training_subset_filings_list[0:100]:
for filing in vert_training_subset_filings_list:
    ti = datetime.datetime.now()
    print('processing next filing at ', ti)
    
    
### this could be all be packed into a function if nec.
###
    # read in the filing's html
    with open(filing,encoding="utf8") as file:
        file_html = file.read()
    
    # parse the html
    parsed_html = BeautifulSoup(file_html)
    # filter out the html head, css, and cast to lower case
    string_filing = parsed_html.body.text.lower()
    
    ################################################################
    #define candidate paragraphs by clustering of overlapping token-hit-margins
    #
    #------ generate a list of token mathces / "hits"------------------------------
    #
    # collect the start and end indices of each token "hit." into an ugly list of lists of tuples
    lst_of_token_hits_lst = []
    for i in range(len(key_tokens.key_tok[0:10])):
        kt = key_tokens.key_tok[i]
        lst_of_token_hits_lst.append([(str(kt), m.start(), m.end()) for m in re.finditer(kt, string_filing)])
    #
    # flatten the ugly list of lists of tuples into a list of tuples
    flater_list_of_tokhits = [tpl for sublist in lst_of_token_hits_lst for tpl in sublist]
    #
    # order the list of token_hit tuples by starting index
    flater_list_of_tokhits.sort(key = lambda x: x[1])
    #
    #-------- use the token hits to define the bounds of the candidate paragraphs -------
    #
    # initialize a list of candidate paragraphs and a hit tracker
    candidate_paragraphs = []
    hit = 0
    #
    # work through the hits until I exhaust the list
    while hit < len(flater_list_of_tokhits) - 1:
    #    
        # initialize the left and right bound of a paragraph
        leftbound = flater_list_of_tokhits[hit][1] - margin
        rightbound = flater_list_of_tokhits[hit][2] + margin
    #     
        # loop from the hit + 1 (cause we used the former hit to initialize the bounds)
        for i in range(hit + 1, len(flater_list_of_tokhits)):
            # if the next token's start is within the current paragraph's bounds and it isnt the last hit
            if (leftbound < flater_list_of_tokhits[i][1] < rightbound) and (i != len(flater_list_of_tokhits) - 1):
                # expand the right bound with respect to next token's end
                rightbound = flater_list_of_tokhits[i][2] + margin
    #             
            # if next token is outside the bounds of current paragraph or we are at the penultimate hit
            else:
                # if right bound is out of htmls range, then adjust it to the end of the html
                if rightbound > len(string_filing):
                    rightbound = len(string_filing)
                # define current paragraph
                par = string_filing[leftbound:rightbound] ########### (if the code needs to be made more efficient I could store the paragraph start and end indices instead of storing the strings)
                # store the paragraph in a list of candidates
                candidate_paragraphs.append(par)
                # note which hit we need to start on for the next iteration of the while loop
                hit = i
                # now that we've found the outer bounds of the current paragraph we can interrupt the for loop
                break #this won't interrupt the while loop 😊 
    #
    # this is just a repetition of the above routine to handle the last hit. There is probably a better way to handle this but we can enhance that later
    if hit == len(flater_list_of_tokhits)-1:
        leftbound = flater_list_of_tokhits[hit][1] - margin
        rightbound = flater_list_of_tokhits[hit][2] + margin
        if rightbound > len(string_filing):
            rightbound = len(string_filing)
        par = string_filing[leftbound:rightbound]
        candidate_paragraphs.append(par)
    #
    # --------------- store the candidate paragraphs in a df ------------------
    candidate_df = pd.DataFrame(candidate_paragraphs)
    candidate_df.columns = ['cand_par']
    candidate_df['len'] = [len(par) for par in candidate_df.cand_par]
    # --------------- rank the candidate paragraphs by basic length (longer paragraphs correspond to denser clusters)
    candidate_df.sort_values(by = 'len', ascending = False, inplace = True)
    candidate_df.reset_index(inplace = True, drop = True)
    # --------------- filter candidates downto those with 'repurchase' in them
    candidate_df = candidate_df[['repurchase' in par for par in candidate_df.cand_par]]
    candidate_df.reset_index(inplace = True, drop = True)
    # --------------- nominee(s) will be the top 1 - 3 in the filterd df
    nominated = candidate_df.cand_par[0]
    # clean up the nominee for validation
    nom_validatable = re.sub(r'\n+', ' ', nominated) # remove new lines
    nom_validatable = re.sub(r'\s+', ' ', nom_validatable) # trim all repeated whitespace down to one
    # --------------- isolate csv's actual paragraph for valiation
    # extract the accesion number back out of the filing path
    an = re.sub('data/nc_training_filings/', '', filing)
    an = re.sub('.html', '', an)
    # use it to filter down to the csv rows with that an
    actual_paragraph = vert_training_subset_df[vert_training_subset_df.accession_number == an].head(1).paragraph_text
    # extract the string from the resulting pandas series
    actual_paragraph = actual_paragraph.values[0]
    # cast the string to lower case
    actual_paragraph = actual_paragraph.lower()
    # eliminate excess spaces
    actual_paragraph = re.sub(r'\s+', ' ', actual_paragraph)
    
    # moment of truth
    #---------------------------------------------------------
    #print('Actual_paragraph in nom_validatable: ')
    #print('----------', actual_paragraph in nom_validatable)
    
    counter = 0
    for wt in word_tokenize(actual_paragraph):
        if wt in word_tokenize(nom_validatable):
            counter += 1
    #print('word tokens actual_paragraph also in word_tokenise(nom_validatable)')
    #print('---------- counter = ', counter)
    x = round(100*counter/len(word_tokenize(actual_paragraph)),2)
    #print('that is a ', x, '% inclusion')
    #print("-------------------------------------------------")
    #print("")
    
    # keeping score
    total_inclusion.append(actual_paragraph in nom_validatable)
    inclusion_rates.append(x)
    tf = datetime.datetime.now()
    print('finished processing ', len(total_inclusion), 'th filing at ', tf)
    print('process took', tf - ti)
    print("--------------------------")
# Out:
# processing next filing at  2018-06-03 11:32:36.965960
# C:\Users\Suhasini\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\Suhasini\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# finished processing  1 th filing at  2018-06-03 11:32:41.695313
# process took 0:00:04.729353
# --------------------------
# processing next filing at  2018-06-03 11:32:41.695313
# finished processing  2 th filing at  2018-06-03 11:32:44.051017
# process took 0:00:02.355704
# --------------------------
# processing next filing at  2018-06-03 11:32:44.051017
# finished processing  3 th filing at  2018-06-03 11:32:46.335904
# process took 0:00:02.284887
# --------------------------
# processing next filing at  2018-06-03 11:32:46.335904
# finished processing  4 th filing at  2018-06-03 11:32:48.693404
# process took 0:00:02.357500
# --------------------------
# processing next filing at  2018-06-03 11:32:48.694370
# finished processing  5 th filing at  2018-06-03 11:32:53.362993
# process took 0:00:04.668623
# --------------------------
# processing next filing at  2018-06-03 11:32:53.362993
# finished processing  6 th filing at  2018-06-03 11:32:55.374508
# process took 0:00:02.011515
# --------------------------
# processing next filing at  2018-06-03 11:32:55.375506
# finished processing  7 th filing at  2018-06-03 11:32:58.319671
# process took 0:00:02.944165
# --------------------------
# processing next filing at  2018-06-03 11:32:58.320630
# finished processing  8 th filing at  2018-06-03 11:33:03.096896
# process took 0:00:04.776266
# --------------------------
# processing next filing at  2018-06-03 11:33:03.097868
# finished processing  9 th filing at  2018-06-03 11:33:07.526011
# process took 0:00:04.428143
# --------------------------
# processing next filing at  2018-06-03 11:33:07.527009
# finished processing  10 th filing at  2018-06-03 11:33:10.117085
# process took 0:00:02.590076
# --------------------------
# processing next filing at  2018-06-03 11:33:10.117085
# finished processing  11 th filing at  2018-06-03 11:33:13.082159
# process took 0:00:02.965074
# --------------------------
# processing next filing at  2018-06-03 11:33:13.083157
# finished processing  12 th filing at  2018-06-03 11:33:16.029361
# process took 0:00:02.946204
# --------------------------
# processing next filing at  2018-06-03 11:33:16.029361
# finished processing  13 th filing at  2018-06-03 11:33:19.213039
# process took 0:00:03.183678
# --------------------------
# processing next filing at  2018-06-03 11:33:19.214037
# finished processing  14 th filing at  2018-06-03 11:33:23.222319
# process took 0:00:04.008282
# --------------------------
# processing next filing at  2018-06-03 11:33:23.222319
# finished processing  15 th filing at  2018-06-03 11:33:26.706025
# process took 0:00:03.483706
# --------------------------
# processing next filing at  2018-06-03 11:33:26.706025
# finished processing  16 th filing at  2018-06-03 11:33:30.179712
# process took 0:00:03.473687
# --------------------------
# processing next filing at  2018-06-03 11:33:30.179712
# finished processing  17 th filing at  2018-06-03 11:33:34.102316
# process took 0:00:03.922604
# --------------------------
# processing next filing at  2018-06-03 11:33:34.102316
# finished processing  18 th filing at  2018-06-03 11:33:36.758214
# process took 0:00:02.655898
# --------------------------
# processing next filing at  2018-06-03 11:33:36.758214
# finished processing  19 th filing at  2018-06-03 11:33:38.789746
# process took 0:00:02.031532
# --------------------------
# processing next filing at  2018-06-03 11:33:38.790744
# finished processing  20 th filing at  2018-06-03 11:33:39.729269
# process took 0:00:00.938525
# --------------------------
# processing next filing at  2018-06-03 11:33:39.730264
# finished processing  21 th filing at  2018-06-03 11:33:45.738169
# process took 0:00:06.007905
# --------------------------
# processing next filing at  2018-06-03 11:33:45.738169
# finished processing  22 th filing at  2018-06-03 11:33:47.804517
# process took 0:00:02.066348
# --------------------------
# processing next filing at  2018-06-03 11:33:47.805515
# finished processing  23 th filing at  2018-06-03 11:33:50.118375
# process took 0:00:02.312860
# --------------------------
# processing next filing at  2018-06-03 11:33:50.119297
# finished processing  24 th filing at  2018-06-03 11:33:58.497999
# process took 0:00:08.378702
# --------------------------
# processing next filing at  2018-06-03 11:33:58.497999
# finished processing  25 th filing at  2018-06-03 11:34:00.779885
# process took 0:00:02.281886
# --------------------------
# processing next filing at  2018-06-03 11:34:00.780821
# finished processing  26 th filing at  2018-06-03 11:34:03.299055
# process took 0:00:02.518234
# --------------------------
# processing next filing at  2018-06-03 11:34:03.299055
# finished processing  27 th filing at  2018-06-03 11:34:08.575809
# process took 0:00:05.276754
# --------------------------
# processing next filing at  2018-06-03 11:34:08.575809
# finished processing  28 th filing at  2018-06-03 11:34:12.026581
# process took 0:00:03.450772
# --------------------------
# processing next filing at  2018-06-03 11:34:12.027583
# finished processing  29 th filing at  2018-06-03 11:34:14.416237
# process took 0:00:02.388654
# --------------------------
# processing next filing at  2018-06-03 11:34:14.417189
# finished processing  30 th filing at  2018-06-03 11:34:17.873874
# process took 0:00:03.456685
# --------------------------
# processing next filing at  2018-06-03 11:34:17.873874
# finished processing  31 th filing at  2018-06-03 11:34:20.459933
# process took 0:00:02.586059
# --------------------------
# processing next filing at  2018-06-03 11:34:20.460973
# finished processing  32 th filing at  2018-06-03 11:34:23.662386
# process took 0:00:03.201413
# --------------------------
# processing next filing at  2018-06-03 11:34:23.662386
# finished processing  33 th filing at  2018-06-03 11:34:28.062620
# process took 0:00:04.400234
# --------------------------
# processing next filing at  2018-06-03 11:34:28.063618
# finished processing  34 th filing at  2018-06-03 11:34:32.872409
# process took 0:00:04.808791
# --------------------------
# processing next filing at  2018-06-03 11:34:32.873368
# finished processing  35 th filing at  2018-06-03 11:34:34.960963
# process took 0:00:02.087595
# --------------------------
# processing next filing at  2018-06-03 11:34:34.961961
# finished processing  36 th filing at  2018-06-03 11:34:38.595286
# process took 0:00:03.633325
# --------------------------
# processing next filing at  2018-06-03 11:34:38.596238
# finished processing  37 th filing at  2018-06-03 11:34:41.423878
# process took 0:00:02.827640
# --------------------------
# processing next filing at  2018-06-03 11:34:41.423878
# finished processing  38 th filing at  2018-06-03 11:34:43.740683
# process took 0:00:02.316805
# --------------------------
# processing next filing at  2018-06-03 11:34:43.740683
# finished processing  39 th filing at  2018-06-03 11:34:46.173179
# process took 0:00:02.432496
# --------------------------
# processing next filing at  2018-06-03 11:34:46.173179
# finished processing  40 th filing at  2018-06-03 11:34:48.117457
# process took 0:00:01.944278
# --------------------------
# processing next filing at  2018-06-03 11:34:48.117977
# finished processing  41 th filing at  2018-06-03 11:34:50.487674
# process took 0:00:02.369697
# --------------------------
# processing next filing at  2018-06-03 11:34:50.487674
# finished processing  42 th filing at  2018-06-03 11:34:53.904194
# process took 0:00:03.416520
# --------------------------
# processing next filing at  2018-06-03 11:34:53.904194
# finished processing  43 th filing at  2018-06-03 11:34:56.103315
# process took 0:00:02.199121
# --------------------------
# processing next filing at  2018-06-03 11:34:56.103315
# finished processing  44 th filing at  2018-06-03 11:34:59.036471
# process took 0:00:02.933156
# --------------------------
# processing next filing at  2018-06-03 11:34:59.036471
# finished processing  45 th filing at  2018-06-03 11:35:02.422167
# process took 0:00:03.385696
# --------------------------
# processing next filing at  2018-06-03 11:35:02.423127
# finished processing  46 th filing at  2018-06-03 11:35:04.571428
# process took 0:00:02.148301
# --------------------------
# processing next filing at  2018-06-03 11:35:04.571428
# finished processing  47 th filing at  2018-06-03 11:35:07.362919
# process took 0:00:02.791491
# --------------------------
# processing next filing at  2018-06-03 11:35:07.362919
# finished processing  48 th filing at  2018-06-03 11:35:09.120260
# process took 0:00:01.757341
# --------------------------
# processing next filing at  2018-06-03 11:35:09.120260
# finished processing  49 th filing at  2018-06-03 11:35:11.006383
# process took 0:00:01.886123
# --------------------------
# processing next filing at  2018-06-03 11:35:11.006383
# finished processing  50 th filing at  2018-06-03 11:35:14.144919
# process took 0:00:03.138536
# --------------------------
# processing next filing at  2018-06-03 11:35:14.144919
# finished processing  51 th filing at  2018-06-03 11:35:19.743945
# process took 0:00:05.599026
# --------------------------
# processing next filing at  2018-06-03 11:35:19.744941
# finished processing  52 th filing at  2018-06-03 11:35:22.603834
# process took 0:00:02.858893
# --------------------------
# processing next filing at  2018-06-03 11:35:22.603834
# finished processing  53 th filing at  2018-06-03 11:35:25.091073
# process took 0:00:02.487239
# --------------------------
# processing next filing at  2018-06-03 11:35:25.091073
# finished processing  54 th filing at  2018-06-03 11:35:27.320233
# process took 0:00:02.229160
# --------------------------
# processing next filing at  2018-06-03 11:35:27.320233
# finished processing  55 th filing at  2018-06-03 11:35:35.783486
# process took 0:00:08.463253
# --------------------------
# processing next filing at  2018-06-03 11:35:35.783486
# finished processing  56 th filing at  2018-06-03 11:35:38.307849
# process took 0:00:02.524363
# --------------------------
# processing next filing at  2018-06-03 11:35:38.307849
# finished processing  57 th filing at  2018-06-03 11:35:42.851626
# process took 0:00:04.543777
# --------------------------
# processing next filing at  2018-06-03 11:35:42.852578
# finished processing  58 th filing at  2018-06-03 11:35:46.127906
# process took 0:00:03.275328
# --------------------------
# processing next filing at  2018-06-03 11:35:46.127906
# finished processing  59 th filing at  2018-06-03 11:35:47.239848
# process took 0:00:01.111942
# --------------------------
# processing next filing at  2018-06-03 11:35:47.240845
# finished processing  60 th filing at  2018-06-03 11:35:50.040363
# process took 0:00:02.799518
# --------------------------
# processing next filing at  2018-06-03 11:35:50.041360
# finished processing  61 th filing at  2018-06-03 11:35:53.439366
# process took 0:00:03.398006
# --------------------------
# processing next filing at  2018-06-03 11:35:53.439366
# finished processing  62 th filing at  2018-06-03 11:35:56.344505
# process took 0:00:02.905139
# --------------------------
# processing next filing at  2018-06-03 11:35:56.345503
# finished processing  63 th filing at  2018-06-03 11:35:58.494817
# process took 0:00:02.149314
# --------------------------
# processing next filing at  2018-06-03 11:35:58.494817
# finished processing  64 th filing at  2018-06-03 11:36:01.589476
# process took 0:00:03.094659
# --------------------------
# processing next filing at  2018-06-03 11:36:01.590474
# finished processing  65 th filing at  2018-06-03 11:36:05.179878
# process took 0:00:03.589404
# --------------------------
# processing next filing at  2018-06-03 11:36:05.180902
# finished processing  66 th filing at  2018-06-03 11:36:07.023988
# process took 0:00:01.843086
# --------------------------
# processing next filing at  2018-06-03 11:36:07.023988
# finished processing  67 th filing at  2018-06-03 11:36:09.354714
# process took 0:00:02.330726
# --------------------------
# processing next filing at  2018-06-03 11:36:09.354714
# finished processing  68 th filing at  2018-06-03 11:36:11.607688
# process took 0:00:02.252974
# --------------------------
# processing next filing at  2018-06-03 11:36:11.608685
# finished processing  69 th filing at  2018-06-03 11:36:12.827430
# process took 0:00:01.218745
# --------------------------
# processing next filing at  2018-06-03 11:36:12.827430
# finished processing  70 th filing at  2018-06-03 11:36:21.999614
# process took 0:00:09.172184
# --------------------------
# processing next filing at  2018-06-03 11:36:21.999614
# finished processing  71 th filing at  2018-06-03 11:36:23.548474
# process took 0:00:01.548860
# --------------------------
# processing next filing at  2018-06-03 11:36:23.548474
# finished processing  72 th filing at  2018-06-03 11:36:27.731369
# process took 0:00:04.182895
# --------------------------
# processing next filing at  2018-06-03 11:36:27.731369
# finished processing  73 th filing at  2018-06-03 11:36:30.188745
# process took 0:00:02.457376
# --------------------------
# processing next filing at  2018-06-03 11:36:30.189712
# finished processing  74 th filing at  2018-06-03 11:36:34.060996
# process took 0:00:03.871284
# --------------------------
# processing next filing at  2018-06-03 11:36:34.061358
# finished processing  75 th filing at  2018-06-03 11:36:36.063007
# process took 0:00:02.001649
# --------------------------
# processing next filing at  2018-06-03 11:36:36.063007
# finished processing  76 th filing at  2018-06-03 11:36:38.935326
# process took 0:00:02.872319
# --------------------------
# processing next filing at  2018-06-03 11:36:38.936324
# finished processing  77 th filing at  2018-06-03 11:36:42.039057
# process took 0:00:03.102733
# --------------------------
# processing next filing at  2018-06-03 11:36:42.039057
# finished processing  78 th filing at  2018-06-03 11:36:46.108146
# process took 0:00:04.069089
# --------------------------
# processing next filing at  2018-06-03 11:36:46.108146
# finished processing  79 th filing at  2018-06-03 11:36:49.667628
# process took 0:00:03.559482
# --------------------------
# processing next filing at  2018-06-03 11:36:49.668717
# finished processing  80 th filing at  2018-06-03 11:36:53.309889
# process took 0:00:03.641172
# --------------------------
# processing next filing at  2018-06-03 11:36:53.310886
# finished processing  81 th filing at  2018-06-03 11:36:56.897296
# process took 0:00:03.586410
# --------------------------
# processing next filing at  2018-06-03 11:36:56.898293
# finished processing  82 th filing at  2018-06-03 11:37:04.017257
# process took 0:00:07.118964
# --------------------------
# processing next filing at  2018-06-03 11:37:04.017257
# finished processing  83 th filing at  2018-06-03 11:37:07.012868
# process took 0:00:02.995611
# --------------------------
# processing next filing at  2018-06-03 11:37:07.013867
# finished processing  84 th filing at  2018-06-03 11:37:09.161572
# process took 0:00:02.147705
# --------------------------
# processing next filing at  2018-06-03 11:37:09.162151
# finished processing  85 th filing at  2018-06-03 11:37:15.728561
# process took 0:00:06.566410
# --------------------------
# processing next filing at  2018-06-03 11:37:15.728561
# finished processing  86 th filing at  2018-06-03 11:37:19.584250
# process took 0:00:03.855689
# --------------------------
# processing next filing at  2018-06-03 11:37:19.584250
# finished processing  87 th filing at  2018-06-03 11:37:23.746149
# process took 0:00:04.161899
# --------------------------
# processing next filing at  2018-06-03 11:37:23.747146
# finished processing  88 th filing at  2018-06-03 11:37:26.365186
# process took 0:00:02.618040
# --------------------------
# processing next filing at  2018-06-03 11:37:26.366183
# finished processing  89 th filing at  2018-06-03 11:37:29.829021
# process took 0:00:03.462838
# --------------------------
# processing next filing at  2018-06-03 11:37:29.829021
# finished processing  90 th filing at  2018-06-03 11:37:33.233843
# process took 0:00:03.404822
# --------------------------
# processing next filing at  2018-06-03 11:37:33.234930
# finished processing  91 th filing at  2018-06-03 11:37:35.948555
# process took 0:00:02.713625
# --------------------------
# processing next filing at  2018-06-03 11:37:35.948555
# finished processing  92 th filing at  2018-06-03 11:37:39.275703
# process took 0:00:03.327148
# --------------------------
# processing next filing at  2018-06-03 11:37:39.275703
# finished processing  93 th filing at  2018-06-03 11:37:42.727511
# process took 0:00:03.451808
# --------------------------
# processing next filing at  2018-06-03 11:37:42.727511
# finished processing  94 th filing at  2018-06-03 11:37:45.460192
# process took 0:00:02.732681
# --------------------------
# processing next filing at  2018-06-03 11:37:45.460192
# finished processing  95 th filing at  2018-06-03 11:37:47.542569
# process took 0:00:02.082377
# --------------------------
# processing next filing at  2018-06-03 11:37:47.543568
# finished processing  96 th filing at  2018-06-03 11:37:50.839846
# process took 0:00:03.296278
# --------------------------
# processing next filing at  2018-06-03 11:37:50.839846
# finished processing  97 th filing at  2018-06-03 11:37:52.721752
# process took 0:00:01.881906
# --------------------------
# processing next filing at  2018-06-03 11:37:52.721752
# finished processing  98 th filing at  2018-06-03 11:37:54.799198
# process took 0:00:02.077446
# --------------------------
# processing next filing at  2018-06-03 11:37:54.799198
# finished processing  99 th filing at  2018-06-03 11:37:58.791629
# process took 0:00:03.992431
# --------------------------
# processing next filing at  2018-06-03 11:37:58.792212
# finished processing  100 th filing at  2018-06-03 11:38:01.083391
# process took 0:00:02.291179
# --------------------------
# processing next filing at  2018-06-03 11:38:01.083461
# finished processing  101 th filing at  2018-06-03 11:38:03.171925
# process took 0:00:02.088464
# --------------------------
# processing next filing at  2018-06-03 11:38:03.171925
# finished processing  102 th filing at  2018-06-03 11:38:05.120754
# process took 0:00:01.948829
# --------------------------
# processing next filing at  2018-06-03 11:38:05.121802
# finished processing  103 th filing at  2018-06-03 11:38:10.109374
# process took 0:00:04.987572
# --------------------------
# processing next filing at  2018-06-03 11:38:10.110372
# finished processing  104 th filing at  2018-06-03 11:38:12.357362
# process took 0:00:02.246990
# --------------------------
# processing next filing at  2018-06-03 11:38:12.357362
# finished processing  105 th filing at  2018-06-03 11:38:14.304159
# process took 0:00:01.946797
# --------------------------
# processing next filing at  2018-06-03 11:38:14.304159
# finished processing  106 th filing at  2018-06-03 11:38:16.719734
# process took 0:00:02.415575
# --------------------------
# processing next filing at  2018-06-03 11:38:16.719734
# finished processing  107 th filing at  2018-06-03 11:38:19.104622
# process took 0:00:02.384888
# --------------------------
# processing next filing at  2018-06-03 11:38:19.105521
# finished processing  108 th filing at  2018-06-03 11:38:22.006866
# process took 0:00:02.901345
# --------------------------
# processing next filing at  2018-06-03 11:38:22.006866
# finished processing  109 th filing at  2018-06-03 11:38:24.675626
# process took 0:00:02.668760
# --------------------------
# processing next filing at  2018-06-03 11:38:24.675626
# finished processing  110 th filing at  2018-06-03 11:38:29.164624
# process took 0:00:04.488998
# --------------------------
# processing next filing at  2018-06-03 11:38:29.164624
# finished processing  111 th filing at  2018-06-03 11:38:32.467837
# process took 0:00:03.303213
# --------------------------
# processing next filing at  2018-06-03 11:38:32.467837
# finished processing  112 th filing at  2018-06-03 11:38:35.072870
# process took 0:00:02.605033
# --------------------------
# processing next filing at  2018-06-03 11:38:35.072870
# finished processing  113 th filing at  2018-06-03 11:38:38.305265
# process took 0:00:03.232395
# --------------------------
# processing next filing at  2018-06-03 11:38:38.306180
# finished processing  114 th filing at  2018-06-03 11:38:46.452194
# process took 0:00:08.146014
# --------------------------
# processing next filing at  2018-06-03 11:38:46.452194
# finished processing  115 th filing at  2018-06-03 11:38:52.727547
# process took 0:00:06.275353
# --------------------------
# processing next filing at  2018-06-03 11:38:52.728411
# finished processing  116 th filing at  2018-06-03 11:38:55.181889
# process took 0:00:02.453478
# --------------------------
# processing next filing at  2018-06-03 11:38:55.181889
# finished processing  117 th filing at  2018-06-03 11:38:58.895955
# process took 0:00:03.714066
# --------------------------
# processing next filing at  2018-06-03 11:38:58.895955
# finished processing  118 th filing at  2018-06-03 11:39:02.488306
# process took 0:00:03.592351
# --------------------------
# processing next filing at  2018-06-03 11:39:02.488306
# finished processing  119 th filing at  2018-06-03 11:39:07.571557
# process took 0:00:05.083251
# --------------------------
# processing next filing at  2018-06-03 11:39:07.572389
# finished processing  120 th filing at  2018-06-03 11:39:12.764510
# process took 0:00:05.192121
# --------------------------
# processing next filing at  2018-06-03 11:39:12.765503
# finished processing  121 th filing at  2018-06-03 11:39:14.804917
# process took 0:00:02.039414
# --------------------------
# processing next filing at  2018-06-03 11:39:14.805877
# finished processing  122 th filing at  2018-06-03 11:39:17.274456
# process took 0:00:02.468579
# --------------------------
# processing next filing at  2018-06-03 11:39:17.274456
# finished processing  123 th filing at  2018-06-03 11:39:20.136784
# process took 0:00:02.862328
# --------------------------
# processing next filing at  2018-06-03 11:39:20.137737
# finished processing  124 th filing at  2018-06-03 11:39:22.974254
# process took 0:00:02.836517
# --------------------------
# processing next filing at  2018-06-03 11:39:22.974254
# finished processing  125 th filing at  2018-06-03 11:39:27.535029
# process took 0:00:04.560775
# --------------------------
# processing next filing at  2018-06-03 11:39:27.535029
# finished processing  126 th filing at  2018-06-03 11:39:29.797045
# process took 0:00:02.262016
# --------------------------
# processing next filing at  2018-06-03 11:39:29.797978
# finished processing  127 th filing at  2018-06-03 11:39:30.993787
# process took 0:00:01.195809
# --------------------------
# processing next filing at  2018-06-03 11:39:30.994779
# finished processing  128 th filing at  2018-06-03 11:39:36.631841
# process took 0:00:05.637062
# --------------------------
# processing next filing at  2018-06-03 11:39:36.631841
# finished processing  129 th filing at  2018-06-03 11:39:41.002062
# process took 0:00:04.370221
# --------------------------
# processing next filing at  2018-06-03 11:39:41.003056
# finished processing  130 th filing at  2018-06-03 11:39:42.378423
# process took 0:00:01.375367
# --------------------------
# processing next filing at  2018-06-03 11:39:42.378423
# finished processing  131 th filing at  2018-06-03 11:39:48.017865
# process took 0:00:05.639442
# --------------------------
# processing next filing at  2018-06-03 11:39:48.018864
# finished processing  132 th filing at  2018-06-03 11:39:50.272826
# process took 0:00:02.253962
# --------------------------
# processing next filing at  2018-06-03 11:39:50.272826
# finished processing  133 th filing at  2018-06-03 11:39:53.128155
# process took 0:00:02.855329
# --------------------------
# processing next filing at  2018-06-03 11:39:53.128155
# finished processing  134 th filing at  2018-06-03 11:39:58.375216
# process took 0:00:05.247061
# --------------------------
# processing next filing at  2018-06-03 11:39:58.375216
# finished processing  135 th filing at  2018-06-03 11:40:00.882470
# process took 0:00:02.507254
# --------------------------
# processing next filing at  2018-06-03 11:40:00.883473
# finished processing  136 th filing at  2018-06-03 11:40:04.647524
# process took 0:00:03.764051
# --------------------------
# processing next filing at  2018-06-03 11:40:04.647524
# finished processing  137 th filing at  2018-06-03 11:40:06.501563
# process took 0:00:01.854039
# --------------------------
# processing next filing at  2018-06-03 11:40:06.501563
# finished processing  138 th filing at  2018-06-03 11:40:08.564443
# process took 0:00:02.062880
# --------------------------
# processing next filing at  2018-06-03 11:40:08.565440
# finished processing  139 th filing at  2018-06-03 11:40:11.309202
# process took 0:00:02.743762
# --------------------------
# processing next filing at  2018-06-03 11:40:11.310102
# finished processing  140 th filing at  2018-06-03 11:40:15.902824
# process took 0:00:04.592722
# --------------------------
# processing next filing at  2018-06-03 11:40:15.902824
# finished processing  141 th filing at  2018-06-03 11:40:20.046786
# process took 0:00:04.143962
# --------------------------
# processing next filing at  2018-06-03 11:40:20.046786
# finished processing  142 th filing at  2018-06-03 11:40:23.514507
# process took 0:00:03.467721
# --------------------------
# processing next filing at  2018-06-03 11:40:23.514507
# finished processing  143 th filing at  2018-06-03 11:40:26.762872
# process took 0:00:03.248365
# --------------------------
# processing next filing at  2018-06-03 11:40:26.763867
# finished processing  144 th filing at  2018-06-03 11:40:31.495945
# process took 0:00:04.732078
# --------------------------
# processing next filing at  2018-06-03 11:40:31.496943
# finished processing  145 th filing at  2018-06-03 11:40:33.206370
# process took 0:00:01.709427
# --------------------------
# processing next filing at  2018-06-03 11:40:33.206370
# finished processing  146 th filing at  2018-06-03 11:40:35.295046
# process took 0:00:02.088676
# --------------------------
# processing next filing at  2018-06-03 11:40:35.295046
# finished processing  147 th filing at  2018-06-03 11:40:37.851949
# process took 0:00:02.556903
# --------------------------
# processing next filing at  2018-06-03 11:40:37.851949
# finished processing  148 th filing at  2018-06-03 11:40:43.536781
# process took 0:00:05.684832
# --------------------------
# processing next filing at  2018-06-03 11:40:43.536781
# finished processing  149 th filing at  2018-06-03 11:40:55.155124
# process took 0:00:11.618343
# --------------------------
# processing next filing at  2018-06-03 11:40:55.155124
# finished processing  150 th filing at  2018-06-03 11:40:58.392501
# process took 0:00:03.237377
# --------------------------
# processing next filing at  2018-06-03 11:40:58.392501
# finished processing  151 th filing at  2018-06-03 11:41:02.321995
# process took 0:00:03.929494
# --------------------------
# processing next filing at  2018-06-03 11:41:02.323054
# finished processing  152 th filing at  2018-06-03 11:41:07.569962
# process took 0:00:05.246908
# --------------------------
# processing next filing at  2018-06-03 11:41:07.569962
# finished processing  153 th filing at  2018-06-03 11:41:10.050515
# process took 0:00:02.480553
# --------------------------
# processing next filing at  2018-06-03 11:41:10.050515
# finished processing  154 th filing at  2018-06-03 11:41:11.985157
# process took 0:00:01.934642
# --------------------------
# processing next filing at  2018-06-03 11:41:11.985157
# finished processing  155 th filing at  2018-06-03 11:41:14.713861
# process took 0:00:02.728704
# --------------------------
# processing next filing at  2018-06-03 11:41:14.713861
# finished processing  156 th filing at  2018-06-03 11:41:18.969525
# process took 0:00:04.255664
# --------------------------
# processing next filing at  2018-06-03 11:41:18.970487
# finished processing  157 th filing at  2018-06-03 11:41:23.780744
# process took 0:00:04.810257
# --------------------------
# processing next filing at  2018-06-03 11:41:23.780744
# finished processing  158 th filing at  2018-06-03 11:41:26.345958
# process took 0:00:02.565214
# --------------------------
# processing next filing at  2018-06-03 11:41:26.345958
# finished processing  159 th filing at  2018-06-03 11:41:28.625791
# process took 0:00:02.279833
# --------------------------
# processing next filing at  2018-06-03 11:41:28.625791
# finished processing  160 th filing at  2018-06-03 11:41:30.052986
# process took 0:00:01.427195
# --------------------------
# processing next filing at  2018-06-03 11:41:30.052986
# finished processing  161 th filing at  2018-06-03 11:41:31.510079
# process took 0:00:01.457093
# --------------------------
# processing next filing at  2018-06-03 11:41:31.510079
# finished processing  162 th filing at  2018-06-03 11:41:33.992406
# process took 0:00:02.482327
# --------------------------
# processing next filing at  2018-06-03 11:41:33.992406
# finished processing  163 th filing at  2018-06-03 11:41:36.666346
# process took 0:00:02.673940
# --------------------------
# processing next filing at  2018-06-03 11:41:36.666346
# finished processing  164 th filing at  2018-06-03 11:41:38.739714
# process took 0:00:02.073368
# --------------------------
# processing next filing at  2018-06-03 11:41:38.739714
# finished processing  165 th filing at  2018-06-03 11:41:40.860079
# process took 0:00:02.120365
# --------------------------
# processing next filing at  2018-06-03 11:41:40.861041
# finished processing  166 th filing at  2018-06-03 11:41:42.903666
# process took 0:00:02.042625
# --------------------------
# processing next filing at  2018-06-03 11:41:42.904606
# finished processing  167 th filing at  2018-06-03 11:41:46.446149
# process took 0:00:03.541543
# --------------------------
# processing next filing at  2018-06-03 11:41:46.446149
# finished processing  168 th filing at  2018-06-03 11:41:49.325678
# process took 0:00:02.879529
# --------------------------
# processing next filing at  2018-06-03 11:41:49.325678
# finished processing  169 th filing at  2018-06-03 11:41:51.659515
# process took 0:00:02.333837
# --------------------------
# processing next filing at  2018-06-03 11:41:51.660402
# finished processing  170 th filing at  2018-06-03 11:41:55.245041
# process took 0:00:03.584639
# --------------------------
# processing next filing at  2018-06-03 11:41:55.246038
# finished processing  171 th filing at  2018-06-03 11:41:57.654579
# process took 0:00:02.408541
# --------------------------
# processing next filing at  2018-06-03 11:41:57.654579
# finished processing  172 th filing at  2018-06-03 11:41:59.553329
# process took 0:00:01.898750
# --------------------------
# processing next filing at  2018-06-03 11:41:59.553329
# finished processing  173 th filing at  2018-06-03 11:42:02.732740
# process took 0:00:03.179411
# --------------------------
# processing next filing at  2018-06-03 11:42:02.732740
# finished processing  174 th filing at  2018-06-03 11:42:10.365863
# process took 0:00:07.633123
# --------------------------
# processing next filing at  2018-06-03 11:42:10.365863
# finished processing  175 th filing at  2018-06-03 11:42:15.968802
# process took 0:00:05.602939
# --------------------------
# processing next filing at  2018-06-03 11:42:15.968802
# finished processing  176 th filing at  2018-06-03 11:42:19.364720
# process took 0:00:03.395918
# --------------------------
# processing next filing at  2018-06-03 11:42:19.364720
# finished processing  177 th filing at  2018-06-03 11:42:21.706490
# process took 0:00:02.341770
# --------------------------
# processing next filing at  2018-06-03 11:42:21.707570
# finished processing  178 th filing at  2018-06-03 11:42:23.923533
# process took 0:00:02.215963
# --------------------------
# processing next filing at  2018-06-03 11:42:23.924530
# finished processing  179 th filing at  2018-06-03 11:42:25.839464
# process took 0:00:01.914934
# --------------------------
# processing next filing at  2018-06-03 11:42:25.839464
# finished processing  180 th filing at  2018-06-03 11:42:28.306808
# process took 0:00:02.467344
# --------------------------
# processing next filing at  2018-06-03 11:42:28.307902
# finished processing  181 th filing at  2018-06-03 11:42:30.811977
# process took 0:00:02.504075
# --------------------------
# processing next filing at  2018-06-03 11:42:30.812940
# finished processing  182 th filing at  2018-06-03 11:42:32.908337
# process took 0:00:02.095397
# --------------------------
# processing next filing at  2018-06-03 11:42:32.908337
# finished processing  183 th filing at  2018-06-03 11:42:35.273134
# process took 0:00:02.364797
# --------------------------
# processing next filing at  2018-06-03 11:42:35.273134
# finished processing  184 th filing at  2018-06-03 11:42:38.044637
# process took 0:00:02.771503
# --------------------------
# processing next filing at  2018-06-03 11:42:38.045600
# finished processing  185 th filing at  2018-06-03 11:42:44.080493
# process took 0:00:06.034893
# --------------------------
# processing next filing at  2018-06-03 11:42:44.080493
# finished processing  186 th filing at  2018-06-03 11:42:48.004004
# process took 0:00:03.923511
# --------------------------
# processing next filing at  2018-06-03 11:42:48.004969
# finished processing  187 th filing at  2018-06-03 11:42:50.021952
# process took 0:00:02.016983
# --------------------------
# processing next filing at  2018-06-03 11:42:50.021952
# finished processing  188 th filing at  2018-06-03 11:42:54.102081
# process took 0:00:04.080129
# --------------------------
# processing next filing at  2018-06-03 11:42:54.102081
# finished processing  189 th filing at  2018-06-03 11:42:57.235926
# process took 0:00:03.133845
# --------------------------
# processing next filing at  2018-06-03 11:42:57.237035
# finished processing  190 th filing at  2018-06-03 11:42:58.712012
# process took 0:00:01.474977
# --------------------------
# processing next filing at  2018-06-03 11:42:58.712977
# finished processing  191 th filing at  2018-06-03 11:43:03.375545
# process took 0:00:04.662568
# --------------------------
# processing next filing at  2018-06-03 11:43:03.375545
# finished processing  192 th filing at  2018-06-03 11:43:08.964664
# process took 0:00:05.589119
# --------------------------
# processing next filing at  2018-06-03 11:43:08.965564
# finished processing  193 th filing at  2018-06-03 11:43:12.892088
# process took 0:00:03.926524
# --------------------------
# processing next filing at  2018-06-03 11:43:12.893104
# finished processing  194 th filing at  2018-06-03 11:43:15.381520
# process took 0:00:02.488416
# --------------------------
# processing next filing at  2018-06-03 11:43:15.381520
# finished processing  195 th filing at  2018-06-03 11:43:22.240094
# process took 0:00:06.858574
# --------------------------
# processing next filing at  2018-06-03 11:43:22.240094
# finished processing  196 th filing at  2018-06-03 11:43:26.326234
# process took 0:00:04.086140
# --------------------------
# processing next filing at  2018-06-03 11:43:26.327139
# finished processing  197 th filing at  2018-06-03 11:43:29.376986
# process took 0:00:03.049847
# --------------------------
# processing next filing at  2018-06-03 11:43:29.378052
# finished processing  198 th filing at  2018-06-03 11:43:32.632963
# process took 0:00:03.254911
# --------------------------
# processing next filing at  2018-06-03 11:43:32.633960
# finished processing  199 th filing at  2018-06-03 11:43:36.969466
# process took 0:00:04.335506
# --------------------------
# processing next filing at  2018-06-03 11:43:36.970379
# finished processing  200 th filing at  2018-06-03 11:43:39.808777
# process took 0:00:02.838398
# --------------------------
# processing next filing at  2018-06-03 11:43:39.809772
# finished processing  201 th filing at  2018-06-03 11:43:42.676138
# process took 0:00:02.866366
# --------------------------
# processing next filing at  2018-06-03 11:43:42.676138
# finished processing  202 th filing at  2018-06-03 11:43:44.865301
# process took 0:00:02.189163
# --------------------------
# processing next filing at  2018-06-03 11:43:44.865301
# finished processing  203 th filing at  2018-06-03 11:43:47.234919
# process took 0:00:02.369618
# --------------------------
# processing next filing at  2018-06-03 11:43:47.236514
# finished processing  204 th filing at  2018-06-03 11:43:50.550129
# process took 0:00:03.313615
# --------------------------
# processing next filing at  2018-06-03 11:43:50.551082
# finished processing  205 th filing at  2018-06-03 11:43:53.515168
# process took 0:00:02.964086
# --------------------------
# processing next filing at  2018-06-03 11:43:53.515168
# finished processing  206 th filing at  2018-06-03 11:43:56.348583
# process took 0:00:02.833415
# --------------------------
# processing next filing at  2018-06-03 11:43:56.348583
# finished processing  207 th filing at  2018-06-03 11:43:58.818023
# process took 0:00:02.469440
# --------------------------
# processing next filing at  2018-06-03 11:43:58.818023
# finished processing  208 th filing at  2018-06-03 11:44:01.931006
# process took 0:00:03.112983
# --------------------------
# processing next filing at  2018-06-03 11:44:01.931006
# finished processing  209 th filing at  2018-06-03 11:44:04.529154
# process took 0:00:02.598148
# --------------------------
# processing next filing at  2018-06-03 11:44:04.529154
# finished processing  210 th filing at  2018-06-03 11:44:07.646720
# process took 0:00:03.117566
# --------------------------
# processing next filing at  2018-06-03 11:44:07.646720
# finished processing  211 th filing at  2018-06-03 11:44:09.609518
# process took 0:00:01.962798
# --------------------------
# processing next filing at  2018-06-03 11:44:09.609518
# finished processing  212 th filing at  2018-06-03 11:44:13.118230
# process took 0:00:03.508712
# --------------------------
# processing next filing at  2018-06-03 11:44:13.119182
# finished processing  213 th filing at  2018-06-03 11:44:15.315338
# process took 0:00:02.196156
# --------------------------
# processing next filing at  2018-06-03 11:44:15.315338
# finished processing  214 th filing at  2018-06-03 11:44:17.883375
# process took 0:00:02.568037
# --------------------------
# processing next filing at  2018-06-03 11:44:17.883375
# finished processing  215 th filing at  2018-06-03 11:44:20.637894
# process took 0:00:02.754519
# --------------------------
# processing next filing at  2018-06-03 11:44:20.638397
# finished processing  216 th filing at  2018-06-03 11:44:23.708683
# process took 0:00:03.070286
# --------------------------
# processing next filing at  2018-06-03 11:44:23.708683
# finished processing  217 th filing at  2018-06-03 11:44:27.728932
# process took 0:00:04.020249
# --------------------------
# processing next filing at  2018-06-03 11:44:27.728932
# finished processing  218 th filing at  2018-06-03 11:44:32.780414
# process took 0:00:05.051482
# --------------------------
# processing next filing at  2018-06-03 11:44:32.780414
# finished processing  219 th filing at  2018-06-03 11:44:37.418964
# process took 0:00:04.638550
# --------------------------
# processing next filing at  2018-06-03 11:44:37.419961
# finished processing  220 th filing at  2018-06-03 11:44:38.348972
# process took 0:00:00.929011
# --------------------------
# processing next filing at  2018-06-03 11:44:38.350041
# finished processing  221 th filing at  2018-06-03 11:44:40.640508
# process took 0:00:02.290467
# --------------------------
# processing next filing at  2018-06-03 11:44:40.640508
# finished processing  222 th filing at  2018-06-03 11:44:44.871199
# process took 0:00:04.230691
# --------------------------
# processing next filing at  2018-06-03 11:44:44.871199
# finished processing  223 th filing at  2018-06-03 11:44:50.333654
# process took 0:00:05.462455
# --------------------------
# processing next filing at  2018-06-03 11:44:50.334587
# finished processing  224 th filing at  2018-06-03 11:44:52.172672
# process took 0:00:01.838085
# --------------------------
# processing next filing at  2018-06-03 11:44:52.172672
# finished processing  225 th filing at  2018-06-03 11:44:53.251837
# process took 0:00:01.079165
# --------------------------
# processing next filing at  2018-06-03 11:44:53.251837
# finished processing  226 th filing at  2018-06-03 11:44:55.431956
# process took 0:00:02.180119
# --------------------------
# processing next filing at  2018-06-03 11:44:55.431956
# finished processing  227 th filing at  2018-06-03 11:44:57.724829
# process took 0:00:02.292873
# --------------------------
# processing next filing at  2018-06-03 11:44:57.725828
# finished processing  228 th filing at  2018-06-03 11:45:00.044622
# process took 0:00:02.318794
# --------------------------
# processing next filing at  2018-06-03 11:45:00.044622
# finished processing  229 th filing at  2018-06-03 11:45:02.942465
# process took 0:00:02.897843
# --------------------------
# processing next filing at  2018-06-03 11:45:02.943985
# finished processing  230 th filing at  2018-06-03 11:45:06.334390
# process took 0:00:03.390405
# --------------------------
# processing next filing at  2018-06-03 11:45:06.334390
# finished processing  231 th filing at  2018-06-03 11:45:09.470007
# process took 0:00:03.135617
# --------------------------
# processing next filing at  2018-06-03 11:45:09.470007
# finished processing  232 th filing at  2018-06-03 11:45:12.192722
# process took 0:00:02.722715
# --------------------------
# processing next filing at  2018-06-03 11:45:12.193783
# finished processing  233 th filing at  2018-06-03 11:45:15.481928
# process took 0:00:03.288145
# --------------------------
# processing next filing at  2018-06-03 11:45:15.481928
# finished processing  234 th filing at  2018-06-03 11:45:22.840329
# process took 0:00:07.358401
# --------------------------
# processing next filing at  2018-06-03 11:45:22.840329
# finished processing  235 th filing at  2018-06-03 11:45:26.639093
# process took 0:00:03.798764
# --------------------------
# processing next filing at  2018-06-03 11:45:26.639093
# finished processing  236 th filing at  2018-06-03 11:45:29.675974
# process took 0:00:03.036881
# --------------------------
# processing next filing at  2018-06-03 11:45:29.675974
# finished processing  237 th filing at  2018-06-03 11:45:32.501528
# process took 0:00:02.825554
# --------------------------
# processing next filing at  2018-06-03 11:45:32.501528
# finished processing  238 th filing at  2018-06-03 11:45:34.693555
# process took 0:00:02.192027
# --------------------------
# processing next filing at  2018-06-03 11:45:34.693555
# finished processing  239 th filing at  2018-06-03 11:45:38.754700
# process took 0:00:04.061145
# --------------------------
# processing next filing at  2018-06-03 11:45:38.755698
# finished processing  240 th filing at  2018-06-03 11:45:39.885324
# process took 0:00:01.129626
# --------------------------
# processing next filing at  2018-06-03 11:45:39.886319
# finished processing  241 th filing at  2018-06-03 11:45:41.182850
# process took 0:00:01.296531
# --------------------------
# processing next filing at  2018-06-03 11:45:41.183848
# finished processing  242 th filing at  2018-06-03 11:45:47.967707
# process took 0:00:06.783859
# --------------------------
# processing next filing at  2018-06-03 11:45:47.968763
# finished processing  243 th filing at  2018-06-03 11:45:51.885150
# process took 0:00:03.916387
# --------------------------
# processing next filing at  2018-06-03 11:45:51.885150
# finished processing  244 th filing at  2018-06-03 11:45:58.292653
# process took 0:00:06.407503
# --------------------------
# processing next filing at  2018-06-03 11:45:58.293709
# finished processing  245 th filing at  2018-06-03 11:45:59.866449
# process took 0:00:01.572740
# --------------------------
# processing next filing at  2018-06-03 11:45:59.867445
# finished processing  246 th filing at  2018-06-03 11:46:02.436602
# process took 0:00:02.569157
# --------------------------
# processing next filing at  2018-06-03 11:46:02.436602
# finished processing  247 th filing at  2018-06-03 11:46:06.129759
# process took 0:00:03.693157
# --------------------------
# processing next filing at  2018-06-03 11:46:06.129759
# finished processing  248 th filing at  2018-06-03 11:46:08.193179
# process took 0:00:02.063420
# --------------------------
# processing next filing at  2018-06-03 11:46:08.193179
# finished processing  249 th filing at  2018-06-03 11:46:10.038245
# process took 0:00:01.845066
# --------------------------
# processing next filing at  2018-06-03 11:46:10.039243
# finished processing  250 th filing at  2018-06-03 11:46:12.856710
# process took 0:00:02.817467
# --------------------------
# processing next filing at  2018-06-03 11:46:12.856710
# finished processing  251 th filing at  2018-06-03 11:46:21.291667
# process took 0:00:08.434957
# --------------------------
# processing next filing at  2018-06-03 11:46:21.291667
# finished processing  252 th filing at  2018-06-03 11:46:23.486797
# process took 0:00:02.195130
# --------------------------
# processing next filing at  2018-06-03 11:46:23.487913
# finished processing  253 th filing at  2018-06-03 11:46:28.141423
# process took 0:00:04.653510
# --------------------------
# processing next filing at  2018-06-03 11:46:28.141423
# finished processing  254 th filing at  2018-06-03 11:46:30.819272
# process took 0:00:02.677849
# --------------------------
# processing next filing at  2018-06-03 11:46:30.820184
# finished processing  255 th filing at  2018-06-03 11:46:32.711231
# process took 0:00:01.891047
# --------------------------
# processing next filing at  2018-06-03 11:46:32.712172
# finished processing  256 th filing at  2018-06-03 11:46:35.065962
# process took 0:00:02.353790
# --------------------------
# processing next filing at  2018-06-03 11:46:35.065962
# finished processing  257 th filing at  2018-06-03 11:46:36.966922
# process took 0:00:01.900960
# --------------------------
# processing next filing at  2018-06-03 11:46:36.966922
# finished processing  258 th filing at  2018-06-03 11:46:40.226210
# process took 0:00:03.259288
# --------------------------
# processing next filing at  2018-06-03 11:46:40.226210
# finished processing  259 th filing at  2018-06-03 11:46:43.230164
# process took 0:00:03.003954
# --------------------------
# processing next filing at  2018-06-03 11:46:43.230164
# finished processing  260 th filing at  2018-06-03 11:46:46.233435
# process took 0:00:03.003271
# --------------------------
# processing next filing at  2018-06-03 11:46:46.234368
# finished processing  261 th filing at  2018-06-03 11:46:48.584172
# process took 0:00:02.349804
# --------------------------
# processing next filing at  2018-06-03 11:46:48.585084
# finished processing  262 th filing at  2018-06-03 11:46:49.574436
# process took 0:00:00.989352
# --------------------------
# processing next filing at  2018-06-03 11:46:49.574436
# finished processing  263 th filing at  2018-06-03 11:46:51.654920
# process took 0:00:02.080484
# --------------------------
# processing next filing at  2018-06-03 11:46:51.655869
# finished processing  264 th filing at  2018-06-03 11:46:55.046772
# process took 0:00:03.390903
# --------------------------
# processing next filing at  2018-06-03 11:46:55.047771
# finished processing  265 th filing at  2018-06-03 11:46:57.622948
# process took 0:00:02.575177
# --------------------------
# processing next filing at  2018-06-03 11:46:57.622948
# finished processing  266 th filing at  2018-06-03 11:47:01.563446
# process took 0:00:03.940498
# --------------------------
# processing next filing at  2018-06-03 11:47:01.564344
# finished processing  267 th filing at  2018-06-03 11:47:04.167504
# process took 0:00:02.603160
# --------------------------
# processing next filing at  2018-06-03 11:47:04.167504
# finished processing  268 th filing at  2018-06-03 11:47:06.364762
# process took 0:00:02.197258
# --------------------------
# processing next filing at  2018-06-03 11:47:06.365875
# finished processing  269 th filing at  2018-06-03 11:47:11.089929
# process took 0:00:04.724054
# --------------------------
# processing next filing at  2018-06-03 11:47:11.089929
# finished processing  270 th filing at  2018-06-03 11:47:13.392778
# process took 0:00:02.302849
# --------------------------
# processing next filing at  2018-06-03 11:47:13.392778
# finished processing  271 th filing at  2018-06-03 11:47:16.077561
# process took 0:00:02.684783
# --------------------------
# processing next filing at  2018-06-03 11:47:16.078560
# finished processing  272 th filing at  2018-06-03 11:47:20.701178
# process took 0:00:04.622618
# --------------------------
# processing next filing at  2018-06-03 11:47:20.701178
# finished processing  273 th filing at  2018-06-03 11:47:26.053841
# process took 0:00:05.352663
# --------------------------
# processing next filing at  2018-06-03 11:47:26.054840
# finished processing  274 th filing at  2018-06-03 11:47:29.434798
# process took 0:00:03.379958
# --------------------------
# processing next filing at  2018-06-03 11:47:29.434798
# finished processing  275 th filing at  2018-06-03 11:47:32.097928
# process took 0:00:02.663130
# --------------------------
# processing next filing at  2018-06-03 11:47:32.097928
# finished processing  276 th filing at  2018-06-03 11:47:36.158681
# process took 0:00:04.060753
# --------------------------
# processing next filing at  2018-06-03 11:47:36.158681
# finished processing  277 th filing at  2018-06-03 11:47:37.295714
# process took 0:00:01.137033
# --------------------------
# processing next filing at  2018-06-03 11:47:37.295714
# finished processing  278 th filing at  2018-06-03 11:47:40.586843
# process took 0:00:03.291129
# --------------------------
# processing next filing at  2018-06-03 11:47:40.586843
# finished processing  279 th filing at  2018-06-03 11:47:44.982092
# process took 0:00:04.395249
# --------------------------
# processing next filing at  2018-06-03 11:47:44.983085
# finished processing  280 th filing at  2018-06-03 11:47:47.411592
# process took 0:00:02.428507
# --------------------------
# processing next filing at  2018-06-03 11:47:47.411592
# finished processing  281 th filing at  2018-06-03 11:47:50.569148
# process took 0:00:03.157556
# --------------------------
# processing next filing at  2018-06-03 11:47:50.569148
# finished processing  282 th filing at  2018-06-03 11:47:55.072221
# process took 0:00:04.503073
# --------------------------
# processing next filing at  2018-06-03 11:47:55.072221
# finished processing  283 th filing at  2018-06-03 11:48:03.144709
# process took 0:00:08.072488
# --------------------------
# processing next filing at  2018-06-03 11:48:03.145177
# finished processing  284 th filing at  2018-06-03 11:48:06.715732
# process took 0:00:03.570555
# --------------------------
# processing next filing at  2018-06-03 11:48:06.715732
# finished processing  285 th filing at  2018-06-03 11:48:09.127317
# process took 0:00:02.411585
# --------------------------
# processing next filing at  2018-06-03 11:48:09.127317
# finished processing  286 th filing at  2018-06-03 11:48:10.871721
# process took 0:00:01.744404
# --------------------------
# processing next filing at  2018-06-03 11:48:10.871721
# finished processing  287 th filing at  2018-06-03 11:48:13.686097
# process took 0:00:02.814376
# --------------------------
# processing next filing at  2018-06-03 11:48:13.686619
# finished processing  288 th filing at  2018-06-03 11:48:21.392525
# process took 0:00:07.705906
# --------------------------
# processing next filing at  2018-06-03 11:48:21.392525
# finished processing  289 th filing at  2018-06-03 11:48:22.807763
# process took 0:00:01.415238
# --------------------------
# processing next filing at  2018-06-03 11:48:22.807763
# finished processing  290 th filing at  2018-06-03 11:48:26.345307
# process took 0:00:03.537544
# --------------------------
# processing next filing at  2018-06-03 11:48:26.346241
# finished processing  291 th filing at  2018-06-03 11:48:28.620163
# process took 0:00:02.273922
# --------------------------
# processing next filing at  2018-06-03 11:48:28.621157
# finished processing  292 th filing at  2018-06-03 11:48:31.938778
# process took 0:00:03.317621
# --------------------------
# processing next filing at  2018-06-03 11:48:31.938778
# finished processing  293 th filing at  2018-06-03 11:48:38.999261
# process took 0:00:07.060483
# --------------------------
# processing next filing at  2018-06-03 11:48:38.999261
# finished processing  294 th filing at  2018-06-03 11:48:40.961066
# process took 0:00:01.961805
# --------------------------
# processing next filing at  2018-06-03 11:48:40.961066
# finished processing  295 th filing at  2018-06-03 11:48:43.676726
# process took 0:00:02.715660
# --------------------------
# processing next filing at  2018-06-03 11:48:43.676726
# finished processing  296 th filing at  2018-06-03 11:48:46.300787
# process took 0:00:02.624061
# --------------------------
# processing next filing at  2018-06-03 11:48:46.301741
# finished processing  297 th filing at  2018-06-03 11:48:49.063154
# process took 0:00:02.761413
# --------------------------
# processing next filing at  2018-06-03 11:48:49.063154
# finished processing  298 th filing at  2018-06-03 11:48:51.206473
# process took 0:00:02.143319
# --------------------------
# processing next filing at  2018-06-03 11:48:51.206473
# finished processing  299 th filing at  2018-06-03 11:48:53.697874
# process took 0:00:02.491401
# --------------------------
# processing next filing at  2018-06-03 11:48:53.698872
# finished processing  300 th filing at  2018-06-03 11:48:55.207303
# process took 0:00:01.508431
# --------------------------
# processing next filing at  2018-06-03 11:48:55.208226
# finished processing  301 th filing at  2018-06-03 11:48:57.195909
# process took 0:00:01.987683
# --------------------------
# processing next filing at  2018-06-03 11:48:57.196907
# finished processing  302 th filing at  2018-06-03 11:49:00.912971
# process took 0:00:03.716064
# --------------------------
# processing next filing at  2018-06-03 11:49:00.913997
# finished processing  303 th filing at  2018-06-03 11:49:03.099156
# process took 0:00:02.185159
# --------------------------
# processing next filing at  2018-06-03 11:49:03.100153
# finished processing  304 th filing at  2018-06-03 11:49:06.777353
# process took 0:00:03.677200
# --------------------------
# processing next filing at  2018-06-03 11:49:06.778312
# finished processing  305 th filing at  2018-06-03 11:49:08.571495
# process took 0:00:01.793183
# --------------------------
# processing next filing at  2018-06-03 11:49:08.572598
# finished processing  306 th filing at  2018-06-03 11:49:11.274571
# process took 0:00:02.701973
# --------------------------
# processing next filing at  2018-06-03 11:49:11.275261
# finished processing  307 th filing at  2018-06-03 11:49:15.156700
# process took 0:00:03.881439
# --------------------------
# processing next filing at  2018-06-03 11:49:15.156700
# finished processing  308 th filing at  2018-06-03 11:49:17.479425
# process took 0:00:02.322725
# --------------------------
# processing next filing at  2018-06-03 11:49:17.479425
# finished processing  309 th filing at  2018-06-03 11:49:19.490048
# process took 0:00:02.010623
# --------------------------
# processing next filing at  2018-06-03 11:49:19.490048
# finished processing  310 th filing at  2018-06-03 11:49:21.695340
# process took 0:00:02.205292
# --------------------------
# processing next filing at  2018-06-03 11:49:21.695340
# finished processing  311 th filing at  2018-06-03 11:49:23.427667
# process took 0:00:01.732327
# --------------------------
# processing next filing at  2018-06-03 11:49:23.427667
# finished processing  312 th filing at  2018-06-03 11:49:25.818648
# process took 0:00:02.390981
# --------------------------
# processing next filing at  2018-06-03 11:49:25.818648
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    2476             return self._engine.get_value(s, k,
# -> 2477                                           tz=getattr(series.dtype, 'tz', None))
#    2478         except KeyError as e1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-34-ef100353622f> in <module>()
#      92     candidate_df.reset_index(inplace = True, drop = True)
#      93     # --------------- nominee(s) will be the top 1 - 3 in the filterd df
# ---> 94     nominated = candidate_df.cand_par[0]
#      95     # clean up the nominee for validation
#      96     nom_validatable = re.sub(r'\n+', ' ', nominated) # remove new lines
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     599         key = com._apply_if_callable(key, self)
#     600         try:
# --> 601             result = self.index.get_value(self, key)
#     602
#     603             if not is_scalar(result):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    2481
#    2482             try:
# -> 2483                 return libts.get_value_box(s, key)
#    2484             except IndexError:
#    2485                 raise
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.get_value_box (pandas\_libs\tslib.c:18843)()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.get_value_box (pandas\_libs\tslib.c:18560)()
#
# IndexError: index out of bounds

# %%
print(total_inclusion)
# Out:
# [True, False, False, False, False, True, False, False, False, False, True, True, False, False, True, False, False, True, False, False, False, True, True, False, False, False, False, False, True, False, True, False, False, False, True, False, False, False, True, True, True, True, False, False, True, False, False, False, False, True, True, False, True, False, False, True, False, False, False, True, False, True, True, True, True, True, False, False, False, False, False, False, True, True, False, True, False, False, False, True, False, False, True, True, False, True, True, False, False, True, True, True, False, False, False, True, False, False, True, True, False, False, False, False, True, True, False, True, False, True, False, False, True, False, False, False, False, False, False, False, False, False, True, True, False, False, True, True, False, True, False, True, False, False, True, False, False, False, True, False, False, True, False, True, False, False, False, False, False, False, False, False, False, False, False, True, True, False, True, False, False, False, False, False, False, False, True, False, False, True, False, False, False, True, False, True, True, True, False, False, False, True, False, False, False, True, False, False, False, False, True, False, True, False, False, True, True, True, False, False, True, True, False, True, False, False, False, False, True, False, False, False, True, True, False, False, False, False, False, False, False, True, True, True, False, False, True, True, False, False, True, False, False, False, True, True, False, False, True, False, False, True, False, True, False, False, False, False, False, False, True, True, False, False, True, False, True, True, False, True, False, False, True, True, True, False, False, False, False, True, True, False, True, False, False, False, True, True, False, False, True, True, False, False, False, False, False, True, False, False, True, False, True, False, True, True, True, False, False, False, False, True, True, False, False, False, False, True, True, False, False, False]

# %%
# total filings processed
len(total_inclusion)
# Out:
# 312

# %%
# number of actual paragraphs 100% included
np.array(total_inclusion).sum()
# Out:
# 114

# %%
# total inclusion rate
print(round(100*np.array(total_inclusion).sum()/len(total_inclusion), 2), '% total inclusion')
# Out:
# 36.54 % total inclusion

# %%
# rates of inclusion of actual paragraphs in predicted paragraphs
print(inclusion_rates)
# Out:
# [100.0, 42.03, 77.27, 100.0, 53.85, 100.0, 100.0, 45.71, 66.67, 51.24, 100.0, 100.0, 65.08, 21.05, 100.0, 66.2, 100.0, 100.0, 72.34, 48.78, 39.68, 100.0, 100.0, 99.24, 95.53, 83.33, 81.67, 86.63, 100.0, 86.11, 100.0, 100.0, 94.63, 72.22, 100.0, 78.01, 91.49, 88.71, 100.0, 100.0, 100.0, 100.0, 40.66, 71.43, 100.0, 54.48, 98.11, 52.63, 73.33, 100.0, 100.0, 100.0, 100.0, 42.65, 98.31, 100.0, 100.0, 91.21, 97.96, 100.0, 68.85, 100.0, 100.0, 100.0, 100.0, 100.0, 38.81, 97.06, 70.0, 60.87, 100.0, 84.21, 99.5, 100.0, 63.24, 100.0, 59.46, 67.82, 86.67, 97.37, 57.8, 73.17, 100.0, 100.0, 86.5, 100.0, 100.0, 31.37, 86.83, 100.0, 100.0, 100.0, 97.34, 37.04, 92.86, 100.0, 79.83, 69.23, 100.0, 100.0, 69.05, 96.97, 64.43, 80.26, 100.0, 100.0, 42.86, 100.0, 62.14, 100.0, 96.55, 58.75, 100.0, 91.46, 83.33, 84.95, 63.41, 63.41, 65.22, 60.0, 91.23, 40.54, 100.0, 100.0, 70.69, 60.55, 100.0, 100.0, 100.0, 100.0, 75.5, 100.0, 65.12, 49.52, 99.04, 64.15, 91.43, 75.51, 100.0, 54.78, 75.68, 100.0, 99.12, 100.0, 98.72, 55.77, 2.04, 47.06, 91.89, 87.5, 64.34, 64.81, 98.91, 53.57, 100.0, 100.0, 100.0, 74.14, 97.22, 48.0, 91.3, 79.03, 48.61, 75.0, 86.21, 64.71, 100.0, 51.16, 72.3, 100.0, 100.0, 91.11, 100.0, 100.0, 98.0, 100.0, 100.0, 100.0, 39.39, 99.13, 65.17, 100.0, 64.47, 68.27, 78.21, 100.0, 63.81, 90.82, 98.41, 85.71, 100.0, 85.91, 100.0, 90.0, 56.76, 100.0, 100.0, 100.0, 100.0, 61.79, 99.16, 100.0, 66.34, 100.0, 81.91, 77.66, 75.0, 80.0, 100.0, 64.15, 96.36, 48.31, 100.0, 100.0, 54.17, 47.67, 64.44, 80.56, 98.92, 100.0, 65.75, 100.0, 100.0, 100.0, 86.11, 60.47, 100.0, 100.0, 49.28, 97.5, 100.0, 87.72, 77.94, 67.72, 100.0, 100.0, 86.76, 69.0, 100.0, 92.59, 67.5, 100.0, 82.43, 100.0, 60.0, 53.85, 50.35, 73.68, 69.7, 65.74, 100.0, 100.0, 41.33, 98.86, 100.0, 93.1, 100.0, 100.0, 83.25, 100.0, 51.85, 44.16, 100.0, 100.0, 100.0, 60.78, 81.82, 57.94, 77.65, 100.0, 100.0, 86.99, 100.0, 63.75, 66.25, 76.67, 100.0, 100.0, 61.18, 82.35, 100.0, 100.0, 54.12, 64.0, 58.23, 94.74, 100.0, 100.0, 58.97, 66.67, 99.12, 57.14, 100.0, 93.02, 100.0, 100.0, 100.0, 51.32, 52.78, 100.0, 56.9, 100.0, 100.0, 67.12, 69.39, 99.1, 65.45, 100.0, 100.0, 100.0, 100.0, 59.0]

# %%
plt.hist(inclusion_rates, bins=20)
plt.title('Histogram of inclusion rates')
plt.grid()
plt.show()

# %%
# mean inclusion rate
np.mean(np.array(inclusion_rates))
# Out:
# 83.053557692307692

# %%
# median inclusion rate
np.median(np.array(inclusion_rates))
# Out:
# 92.724999999999994

# %% [markdown]
# ## For now, ranking paragraphs by something as unrefined as brute length is working well enough
# ### filtering the candidate paragraphs to those containing 'repurchase' worked well too.

# %% [markdown]
# ## 🤔 💡
# #### can enhance by counting how many key_token hits each paragraph has
# #### can enhance by assigning weighted values to certain key_tokens

# %%
type(inclusion_rates)
# Out:
# list

# %%
inclusion_rates[:10]
# Out:
# [100.0, 42.03, 77.27, 100.0, 53.85, 100.0, 100.0, 45.71, 66.67, 51.24]

# %%
len(inclusion_rates)
# Out:
# 312
